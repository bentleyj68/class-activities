# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities, color='b',  align="center")
# Out:
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value + 1 for value in x_axis]
plt.xticks(tick_locations, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x2c540bc2278>,
#   <matplotlib.axis.XTick at 0x2c540bc2748>,
#   <matplotlib.axis.XTick at 0x2c540bc2828>,
#   <matplotlib.axis.XTick at 0x2c540bf6f28>,
#   <matplotlib.axis.XTick at 0x2c540c10400>],
#  [Text(0, 0, 'New Orleans'),
#   Text(0, 0, 'Milwaukee'),
#   Text(0, 0, 'Omaha'),
#   Text(0, 0, 'Pittsburgh'),
#   Text(0, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %%
# Set the limits of the y axis
plt.ylim(0,9)
# Out:
# (0.0, 9.0)

# %%
# Give the chart a title, x label, and y label
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bar per 10,000 Households")
# Out:
# Text(0, 0.5, 'Bar per 10,000 Households')

# %%
# Save an image of the chart and print it to the screen
plt.bar(x_axis, bars_in_cities, color='b',  align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(bars_in_cities)+1)
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bar per 10,000 Households")
plt.savefig("Images/BarDensity.png")
plt.show()
