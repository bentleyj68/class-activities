# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Retrieve Google API key from config.py
from config import gkey

# %%
# 1. What are the geocoordinates (latitude/longitude) of Canberra?
target_city = "Canberra Australia"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)

geo_data = requests.get(target_url).json()

lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat, lng))
# Out:
#     City: Canberra Australia
#     Latitude: -35.2809368
#     Longitude: 149.1300092

# %%
# 2. What are the geocoordinates (latitude/longitude) of The Sydney Opera House?
target_landmark = "Sydney Opera House"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_landmark, gkey)

geo_data = requests.get(target_url).json()

lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    Landmark: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_landmark, lat, lng))
# Out:
#     Landmark: Sydney Opera House
#     Latitude: -33.8567844
#     Longitude: 151.2152967

# %%
# 3. Find the name and address of a bike store in Perth.
#    Hint: See https://developers.google.com/places/web-service/supported_types
# geocoordinates
target_coordinates = "-31.9505269, 115.8604572"
target_search = "Bicycle"
target_radius = 8000
target_type = "retail"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# aps.google.com/maps/contrib/116649741565891599522\">Steff Van Amerongen</a>"
#                     ],
#                     "photo_reference": "ATtYBwKrrPfO-x1g3-__NKqoA3p6J8FihS6JN-f8RDMjfMA8oUn-YLiaftrCSi8YIH5ylamrNy-lCVT33lqQLQsQCu_elaX5h72YLpW_vKgQe3-6TpNu-CBOLNMivkkQiDxgXSgUy3uKv218Ezoa0WLgN3mwUmfrlL_wB2JFsBnm12t59qu5",
#                     "width": 4096
#                 }
#             ],
#             "place_id": "ChIJ0zh6U9O6MioRO_ILLg_P9Fc",
#             "plus_code": {
#                 "compound_code": "2VX2+6V Perth, Western Australia",
#                 "global_code": "4PWQ2VX2+6V"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ0zh6U9O6MioRO_ILLg_P9Fc",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
# ...

# %%
# 4. Find a balloon store near Perth.
target_coordinates = "-31.9505269, 115.8604572"
target_search = "Balloon"
target_radius = 8000
target_type = "retail"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
#       "name": "Funky Balloons",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101491558881942971825\">Funky Balloons</a>"
#                     ],
#                     "photo_reference": "ATtYBwI8HgzWVZ_cNRo3rmombVyw_LAgdxI7kF2rK0KLvX8HvcbFDTJolnXkqftoyI81gX2k-aWx4bH-UaNacgMsg4yDASieNRTkfOb1KKtCK0WLI8fSS6y15-nmQ5EnJpwJWq9UawHvq4JSQtrJqWyoXfHNGZTi50kyUymQ0xPhT6gar67E",
#                     "width": 480
#                 }
#             ],
#             "place_id": "ChIJJ6nhaly7MioRl6g71MQjeZc",
#             "plus_code": {
#                 "compound_code": "2V6C+GG Como, Western Australia",
#                 "global_code": "4PWQ2V6C+GG"
#             },
#             "rating": 4.5,
#             "reference": "ChIJJ6nhaly7MioRl6g71MQjeZc",
# ...

# %%
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.

target_coordinates = "-31.9505269, 115.8604572"
target_search = "Dentist"
target_radius = 8000
target_type = "medical"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# "scope": "GOOGLE",
#             "types": [
#                 "dentist",
#                 "doctor",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "322 Stirling Hwy, Claremont"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -31.9362801,
#                     "lng": 115.8400303
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -31.93498127010728,
#                         "lng": 115.8413804298928
#                     },
#                     "southwest": {
#                         "lat": -31.93768092989272,
#                         "lng": 115.8386807701073
#                     }
#                 }
#             },
# ...

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
target_coordinates = "-31.9505269, 115.8604572"
target_search = "restaurant"
target_radius = 8000
target_type = "restaurant"
rating = ">4.8"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "rating" : rating
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# convert response to json
places_data = response.json()

print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
print(places_data["results"][0]["rating"])
# Out:
# Friends Restaurant
# Cloisters, 200 St Georges Terrace, Perth
# 4.7
